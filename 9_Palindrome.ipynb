# %% [markdown]
# PALINDROME

# %%
class solutiom:
  def isPalindrome(self,x:int) -> bool:
    if x<0 or (x%10==0 and x!=0):
       return False
       reverse=0
       num=x
       while x>0:
        last_digit=x%10
        reverse=reverse*10+last_digit
        x=x//10
        return num==reverse
        sol()
number=int(input("Enter the number"))
print("Palindrome",sol. isPalindrome(number))
