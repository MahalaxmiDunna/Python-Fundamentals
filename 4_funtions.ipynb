# %% [markdown]
# functions

# %%
x=5
print("Hello")

#funtion definition
def print_lyrics():
  print("I'm lumberjack and I'm ok")
  print("I sleep all night and I work all day")

print("yo")
print_lyrics()
x=x+5
print(x)
print_lyrics()
# Out:
# Hello
# yo
# I'm lumberjack and I'm ok
# I sleep all night and I work all day
# 10
# I'm lumberjack and I'm ok
# I sleep all night and I work all day

# %%
def greet(lang):
  if lang =="es":
    return "Hola"
  elif lang =="fr":
    return "Bonjour"
  else:
    return "Hello"

  print(greet("Hindi"))
  print(greet("fr"))
  print(greet("es"))

# %%
def addtwo(a,b):
  added=a+b
  return(added)

print("Welcome to user defined funtions")
print("here we have a funtion call")
sum=addtwo(4,5)
print(sum)
# Out:
# Welcome to user defined funtions
# here we have a funtion call
# 9
